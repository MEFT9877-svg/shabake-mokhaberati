# %%
# Given data
import pandas as pd


# Initialize lists to store the results

results = []
car_mass =1550  # Car mass in kg

torque = 300  # Torque in Nm

power =161  # Power in hp

base_accelerator = 9  # Base accelerator in m/s^2

driver_reaction_time = 0.5  # Driver reaction time in seconds

g = 9.81  # Acceleration due to gravity in m/s^2


# Calculating stopping distance, time taken to stop, braking intensity, and deceleration rate

for speed_ms, acceleration in zip(speeds_ms, accelerations):

    # Stopping distance

    stopping_distance = speed_ms ** 2 / (2 * acceleration)



    # Time taken to stop

    time_to_stop = speed_ms / acceleration



    # Braking intensity

    braking_intensity = acceleration / g



    # Deceleration rate

    deceleration_rate = abs(acceleration)



    # Output the results

    print(f"At a speed of {speed_ms:.2f} m/s:")

    print(f"  - Stopping Distance: {stopping_distance:.2f} meters")

    print(f"  - Time Taken to Stop: {time_to_stop:.2f} seconds")

    print(f"  - Braking Intensity: {braking_intensity:.2f}")

    print(f"  - Deceleration Rate: {deceleration_rate:.2f} m/s^2")

    print(f"  - Driver Reaction Time: {driver_reaction_time} seconds\n")
    # Create a DataFrame from the results

df = pd.DataFrame(results, columns=['Speed (km/h)', 'Stopping Distance (m)', 'Time to Stop (s)', 'Braking Intensity', 'Deceleration Rate (m/s^2)', 'Driver Reaction Time (s)'])


# Export the DataFrame to an Excel file

df.to_excel('stopping_parameters.xlsx', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e5d7d4c0a5b3> in <cell line: 23>()
#      21 # Calculating stopping distance, time taken to stop, braking intensity, and deceleration rate
#      22
# ---> 23 for speed_ms, acceleration in zip(speeds_ms, accelerations):
#      24
#      25     # Stopping distance
#
# NameError: name 'speeds_ms' is not defined

# %%
# Given data

import pandas as pd


# Initialize lists to store the results

results = []

car_mass = 1268  # Car mass in kg

torque = 144  # Torque in Nm

power = 113  # Power in hp

driver_reaction_time = 2  # Driver reaction time in seconds

g = 9.81  # Acceleration due to gravity in m/s^2


# Define a function to calculate acceleration based on speed

def calculate_acceleration(speed_ms):

    # Calculate the force applied by the engine

    force_engine = power * 735.5 / speed_ms  # Convert power from hp to watts

    # Calculate the total force (including rolling resistance and air resistance)

    total_force = force_engine - (0.01 * speed_ms) - (0.5 * 1.225 * speed_ms**2)

    # Calculate the acceleration

    acceleration = total_force / car_mass

    return acceleration


# Define a list of speeds in m/s

speeds_ms = [10, 20, 30]  # Example speeds


# Calculating stopping distance, time taken to stop, braking intensity, and deceleration rate

for speed_ms in speeds_ms:

    # Calculate acceleration

    acceleration = calculate_acceleration(speed_ms)



    # Stopping distance

    stopping_distance = speed_ms ** 2 / (2 * acceleration)



    # Time taken to stop

    time_to_stop = speed_ms / acceleration



    # Braking intensity

    braking_intensity = acceleration / g



    # Deceleration rate

    deceleration_rate = abs(acceleration)



    # Output the results

    print(f"At a speed of {speed_ms:.2f} m/s:")

    print(f"  - Stopping Distance: {stopping_distance:.2f} meters")

    print(f"  - Time Taken to Stop: {time_to_stop:.2f} seconds")

    print(f"  - Braking Intensity: {braking_intensity:.2f}")

    print(f"  - Deceleration Rate: {deceleration_rate:.2f} m/s^2")

    print(f"  - Driver Reaction Time: {driver_reaction_time} seconds\n")



    # Append results to the list

    results.append([speed_ms * 3.6, stopping_distance, time_to_stop, braking_intensity, deceleration_rate, driver_reaction_time])


# Create a DataFrame from the results

df = pd.DataFrame(results, columns=['Speed (km/h)', 'Stopping Distance (m)', 'Time to Stop (s)', 'Braking Intensity', 'Deceleration Rate (m/s^2)', 'Driver Reaction Time (s)'])


# Export the DataFrame to an Excel file

df.to_excel('stopping_parameters.xlsx', index=False)
# Out:
# At a speed of 10.00 m/s:
#   - Stopping Distance: 7.69 meters
#   - Time Taken to Stop: 1.54 seconds
#   - Braking Intensity: 0.66
#   - Deceleration Rate: 6.51 m/s^2
#   - Driver Reaction Time: 2 seconds
#
# At a speed of 20.00 m/s:
#   - Stopping Distance: 64.85 meters
#   - Time Taken to Stop: 6.49 seconds
#   - Braking Intensity: 0.31
#   - Deceleration Rate: 3.08 m/s^2
#   - Driver Reaction Time: 2 seconds
#
# At a speed of 30.00 m/s:
#   - Stopping Distance: 257.16 meters
#   - Time Taken to Stop: 17.14 seconds
#   - Braking Intensity: 0.18
#   - Deceleration Rate: 1.75 m/s^2
#   - Driver Reaction Time: 2 seconds

# %%
# Given data

import pandas as pd
from google.colab import files

files.download('stopping_parameters.xlsx')

# Initialize lists to store the results

results = []

car_mass = 1268  # Car mass in kg

torque = 144  # Torque in Nm

power = 113  # Power in hp

driver_reaction_time = 2  # Driver reaction time in seconds

g = 9.81  # Acceleration due to gravity in m/s^2


# Define a function to calculate acceleration based on speed

def calculate_acceleration(speed_ms):

    # Calculate the force applied by the engine

    force_engine = power * 735.5 / speed_ms  # Convert power from hp to watts

    # Calculate the total force (including rolling resistance and air resistance)

    total_force = force_engine - (0.01 * speed_ms) - (0.5 * 1.225 * speed_ms**2)

    # Calculate the acceleration

    acceleration = total_force / car_mass

    return acceleration


# Define a list of speeds in m/s

speeds_ms = [10, 20, 30]  # Example speeds


# Calculating stopping distance, time taken to stop, braking intensity, and deceleration rate

for speed_ms in speeds_ms:

    # Calculate acceleration

    acceleration = calculate_acceleration(speed_ms)



    # Stopping distance

    stopping_distance = speed_ms ** 2 / (2 * acceleration)



    # Time taken to stop

    time_to_stop = speed_ms / acceleration



    # Braking intensity

    braking_intensity = acceleration / g



    # Deceleration rate

    deceleration_rate = abs(acceleration)



    # Output the results

    print(f"At a speed of {speed_ms:.2f} m/s:")

    print(f"  - Stopping Distance: {stopping_distance:.2f} meters")

    print(f"  - Time Taken to Stop: {time_to_stop:.2f} seconds")

    print(f"  - Braking Intensity: {braking_intensity:.2f}")

    print(f"  - Deceleration Rate: {deceleration_rate:.2f} m/s^2")

    print(f"  - Driver Reaction Time: {driver_reaction_time} seconds\n")



    # Append results to the list

    results.append([speed_ms * 3.6, stopping_distance, time_to_stop, braking_intensity, deceleration_rate, driver_reaction_time])


# Create a DataFrame from the results

df = pd.DataFrame(results, columns=['Speed (km/h)', 'Stopping Distance (m)', 'Time to Stop (s)', 'Braking Intensity', 'Deceleration Rate (m/s^2)', 'Driver Reaction Time (s)'])


# Export the DataFrame to an Excel file

df.to_excel('stopping_parameters.xlsx', index=False)
# Out:
# At a speed of 10.00 m/s:
#   - Stopping Distance: 7.69 meters
#   - Time Taken to Stop: 1.54 seconds
#   - Braking Intensity: 0.66
#   - Deceleration Rate: 6.51 m/s^2
#   - Driver Reaction Time: 2 seconds
#
# At a speed of 20.00 m/s:
#   - Stopping Distance: 64.85 meters
#   - Time Taken to Stop: 6.49 seconds
#   - Braking Intensity: 0.31
#   - Deceleration Rate: 3.08 m/s^2
#   - Driver Reaction Time: 2 seconds
#
# At a speed of 30.00 m/s:
#   - Stopping Distance: 257.16 meters
#   - Time Taken to Stop: 17.14 seconds
#   - Braking Intensity: 0.18
#   - Deceleration Rate: 1.75 m/s^2
#   - Driver Reaction Time: 2 seconds

# %%
# Given data

import pandas as pd

from google.colab import files


# Initialize lists to store the results

results = []

car_mass = 1268  # Car mass in kg

torque = 144  # Torque in Nm

power = 113  # Power in hp

driver_reaction_time = 2  # Driver reaction time in seconds

g = 9.81  # Acceleration due to gravity in m/s^2


# Define a function to calculate acceleration based on speed

def calculate_acceleration(speed_ms):

    force_engine = power * 735.5 / speed_ms  # Calculate force applied by the engine

    total_force = force_engine - (0.01 * speed_ms) - (0.5 * 1.225 * speed_ms**2)  # Calculate total force

    acceleration = total_force / car_mass  # Calculate acceleration

    return acceleration


# Define a list of speeds in km/h

speeds_kmh = range(20, 161, 20)  # Speeds from 20 km/h to 160 km/h in steps of 20


# Calculating stopping distance, time taken to stop, braking intensity, and deceleration rate for the new range of speeds

for speed_kmh in speeds_kmh:

    speed_ms = speed_kmh / 3.6  # Convert speed from km/h to m/s

    acceleration = calculate_acceleration(speed_ms)  # Calculate acceleration



    stopping_distance = speed_ms ** 2 / (2 * acceleration)  # Calculate stopping distance

    time_to_stop = speed_ms / acceleration  # Calculate time taken to stop

    braking_intensity = acceleration / g  # Calculate braking intensity

    deceleration_rate = abs(acceleration)  # Calculate deceleration rate



    # Output the results

    print(f"At a speed of {speed_kmh} km/h:")

    print(f"  - Stopping Distance: {stopping_distance:.2f} meters")

    print(f"  - Time Taken to Stop: {time_to_stop:.2f} seconds")

    print(f"  - Braking Intensity: {braking_intensity:.2f}")

    print(f"  - Deceleration Rate: {deceleration_rate:.2f} m/s^2")

    print(f"  - Driver Reaction Time: {driver_reaction_time} seconds\n")



    # Append results to the list

    results.append([speed_kmh, stopping_distance, time_to_stop, braking_intensity, deceleration_rate, driver_reaction_time])


# Create a DataFrame from the results

df = pd.DataFrame(results, columns=['Speed (km/h)', 'Stopping Distance (m)', 'Time to Stop (s)', 'Braking Intensity', 'Deceleration Rate (m/s^2)', 'Driver Reaction Time (s)'])


# Export the DataFrame to an Excel file

df.to_excel('stopping_parameters.xlsx', index=False)


# Download the Excel file

files.download('stopping_parameters.xlsx')
# Out:
# At a speed of 20 km/h:
#   - Stopping Distance: 1.31 meters
#   - Time Taken to Stop: 0.47 seconds
#   - Braking Intensity: 1.20
#   - Deceleration Rate: 11.78 m/s^2
#   - Driver Reaction Time: 2 seconds
#
# At a speed of 40 km/h:
#   - Stopping Distance: 10.57 meters
#   - Time Taken to Stop: 1.90 seconds
#   - Braking Intensity: 0.60
#   - Deceleration Rate: 5.84 m/s^2
#   - Driver Reaction Time: 2 seconds
#
# At a speed of 60 km/h:
#   - Stopping Distance: 36.57 meters
#   - Time Taken to Stop: 4.39 seconds
#   - Braking Intensity: 0.39
#   - Deceleration Rate: 3.80 m/s^2
#   - Driver Reaction Time: 2 seconds
#
# At a speed of 80 km/h:
#   - Stopping Distance: 91.08 meters
#   - Time Taken to Stop: 8.20 seconds
#   - Braking Intensity: 0.28
#   - Deceleration Rate: 2.71 m/s^2
#   - Driver Reaction Time: 2 seconds
#
# At a speed of 100 km/h:
#   - Stopping Distance: 194.19 meters
#   - Time Taken to Stop: 13.98 seconds
#   - Braking Intensity: 0.20
# ...

# %%
# Given data

import pandas as pd

from google.colab import files


# Initialize lists to store the results

results = []

car_mass = 1550  # Car mass in kg

torque = 300  # Torque in Nm

power = 161  # Power in hp

driver_reaction_time = 0.5  # Driver reaction time in seconds

g = 9.81  # Acceleration due to gravity in m/s^2


# Define a function to calculate acceleration based on speed

def calculate_acceleration(speed_ms):

    force_engine = power * 735.5 / speed_ms  # Calculate force applied by the engine

    total_force = force_engine - (0.01 * speed_ms) - (0.5 * 1.225 * speed_ms**2)  # Calculate total force

    acceleration = total_force / car_mass  # Calculate acceleration

    return acceleration


# Define a list of speeds in km/h with a step of 1 km/h

speeds_kmh = range(20,141)  # Speeds from 20 km/h to 140 km/h


# Calculating stopping distance, time taken to stop, braking intensity, and deceleration rate for the new range of speeds

for speed_kmh in speeds_kmh:

    speed_ms = speed_kmh / 3.6  # Convert speed from km/h to m/s

    acceleration = calculate_acceleration(speed_ms)  # Calculate acceleration



    stopping_distance = speed_ms ** 2 / (2 * acceleration)  # Calculate stopping distance

    time_to_stop = speed_ms / acceleration  # Calculate time taken to stop

    braking_intensity = acceleration / g  # Calculate braking intensity

    deceleration_rate = abs(acceleration)  # Calculate deceleration rate



    # Output the results

    print(f"At a speed of {speed_kmh} km/h:")

    print(f"  - Stopping Distance: {stopping_distance:.2f} meters")

    print(f"  - Time Taken to Stop: {time_to_stop:.2f} seconds")

    print(f"  - Braking Intensity: {braking_intensity:.2f}")

    print(f"  - Deceleration Rate: {deceleration_rate:.2f} m/s^2")

    print(f"  - Driver Reaction Time: {driver_reaction_time} seconds\n")



    # Append results to the list

    results.append([speed_kmh, stopping_distance, time_to_stop, braking_intensity, deceleration_rate, driver_reaction_time])


# Create a DataFrame from the results

df = pd.DataFrame(results, columns=['Speed (km/h)', 'Stopping Distance (m)', 'Time to Stop (s)', 'Braking Intensity', 'Deceleration Rate (m/s^2)', 'Driver Reaction Time (s)'])


# Export the DataFrame to an Excel file

df.to_excel('stopping_parameters.xlsx', index=False)


# Download the Excel file

files.download('stopping_parameters.xlsx')
# Out:
# At a speed of 20 km/h:
#   - Stopping Distance: 1.12 meters
#   - Time Taken to Stop: 0.40 seconds
#   - Braking Intensity: 1.40
#   - Deceleration Rate: 13.74 m/s^2
#   - Driver Reaction Time: 0.5 seconds
#
# At a speed of 21 km/h:
#   - Stopping Distance: 1.30 meters
#   - Time Taken to Stop: 0.45 seconds
#   - Braking Intensity: 1.33
#   - Deceleration Rate: 13.08 m/s^2
#   - Driver Reaction Time: 0.5 seconds
#
# At a speed of 22 km/h:
#   - Stopping Distance: 1.50 meters
#   - Time Taken to Stop: 0.49 seconds
#   - Braking Intensity: 1.27
#   - Deceleration Rate: 12.49 m/s^2
#   - Driver Reaction Time: 0.5 seconds
#
# At a speed of 23 km/h:
#   - Stopping Distance: 1.71 meters
#   - Time Taken to Stop: 0.54 seconds
#   - Braking Intensity: 1.22
#   - Deceleration Rate: 11.94 m/s^2
#   - Driver Reaction Time: 0.5 seconds
#
# At a speed of 24 km/h:
#   - Stopping Distance: 1.94 meters
#   - Time Taken to Stop: 0.58 seconds
#   - Braking Intensity: 1.17
# ...

# %% [markdown]
#     I added a function calculate_acceleration that calculates the acceleration based on the speed by considering the force applied by the engine, rolling resistance, and air resistance.
#     I modified the loop to calculate acceleration based on the speed for each speed in the speeds_ms list.
#     The calculated acceleration is then used to determine the stopping distance, time taken to stop, braking intensity, and deceleration rate for each speed.
#     The results are stored in a DataFrame and exported to an Excel file as before.
